# %%
import sklearn as skl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
'''
Load CSV
'''
df = pd.read_csv('datasets/wine.csv')

# %%
df.birthday = pd.to_datetime(df.birthday)
df['Year'] = df.birthday.dt.year
df['Month'] = df.birthday.dt.month
df['Day_Name'] = df.birthday.dt.day_name(lolcale='pt')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/1j/0ym_j9j544d0fq15xcj3nh0r0000gn/T/ipykernel_75295/1466361272.py in ?()
# ----> 1 df.birthday = pd.to_datetime(df.birthday)
#       2 df['Year'] = df.birthday.dt.year
#       3 df['Month'] = df.birthday.dt.month
#       4 df['Day_Name'] = df.birthday.dt.day_name(lolcale='pt')
#
# ~/miniforge3/envs/qiskit-env/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'birthday'
